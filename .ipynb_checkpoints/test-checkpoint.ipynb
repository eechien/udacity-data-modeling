# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1, datetime.datetime(1970, 1, 1, 0, 25, 43, 537328), 91, 'free', None, None, 829, 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)'),
#  (2, datetime.datetime(1970, 1, 1, 0, 25, 43, 540122), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (3, datetime.datetime(1970, 1, 1, 0, 25, 43, 540369), 73, 'paid', None, None, 1049, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 5;

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, Decimal('218.93179')),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, Decimal('266.39628')),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, Decimal('269.81832')),
#  ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, Decimal('189.57016')),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, Decimal('148.03546'))]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', None, None),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', None, None),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', '', None, None),
#  ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', None, None),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35.14968, -90.04892)]

# %%
# %sql SELECT * FROM time LIMIT 5;

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql SELECT s.song_id, a.artist_id FROM songs s JOIN artists a ON s.artist_id=a.artist_id WHERE s.title = 'Hey_ Soul Sister' AND a.name = 'Train'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT s.title, a.name FROM songs s JOIN artists a ON a.artist_id=s.artist_id
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [("I Didn't Mean To", 'Casual'),
#  ('Insatiable (Instrumental Version)', 'Clp'),
#  ('Pink World', 'Planet P Project'),
#  ('Drop of Rain', 'Tweeterfriendly Music'),
#  ('Soul Deep', 'The Box Tops'),
#  ('The Moon And I (Ordinary Day Album Version)', 'Jeff And Sheri Easter'),
#  ('Keepin It Real (Skit)', 'Rated R'),
#  ('Young Boy Blues', 'JennyAnyKind'),
#  ('Something Girls', 'Adam Ant'),
#  ('Face the Ashes', 'Gob'),
#  ('Amor De Cabaret', 'Sonora Santanera'),
#  ('High Tide', 'Richard Souther'),
#  ('Sohna Nee Sohna Data', 'Faiz Ali Faiz'),
#  ('Floating', 'Blue Rodeo'),
#  ('La Culpa', 'Andy Andy'),
#  ('Auguri Cha Cha', 'Bob Azzam'),
#  ('Caught In A Dream', 'Tesla'),
#  ('Broken-Down Merry-Go-Round', 'Jimmy Wakely'),
#  ('Synthetic Dream', 'lextrical'),
#  ('The Urgency (LP Version)', 'Wayne Watson'),
#  ('Kassie Jones', 'Alice Stuart'),
#  ('Tonight Will Be Alright', 'Lionel Richie'),
# ...
